# %%
using PyPlot

using LinearAlgebra
using SparseArrays
# using Arpack

using GSL
using DifferentialEquations
using Sundials

using PyCall
using LsqFit

using Printf
using Interpolations
using DelimitedFiles
using JLD2

# %%
@load "./en_loss_data/ene_data.jld2" envals_kev ene_loss
# Out:
# 2-element Array{Symbol,1}:
#  :envals_kev
#  :ene_loss

# %%
## Rate Equations Model 
function rate_solve(du,u,p,t)
    Γ41 = p[1];
    Γ24 = p[2];
    Γ34 = p[3];
    Γ12 = p[4];
    Γ13 = p[5];
    
    du[1] = -Γ41*u[1]*(1-u[4]) + Γ12*u[2]*(1-u[1]) + Γ13*u[3]*(1-u[1]);
    du[2] = Γ24*u[4]*(1-u[2]) - Γ12*u[2]*(1-u[1]);
    du[3] = Γ34*u[4]*(1-u[3]) - Γ13*u[3]*(1-u[1]);
    du[4] = Γ41*u[1]*(1-u[4]) - Γ24*u[4]*(1-u[2]) - Γ34*u[4]*(1-u[3]);
end;

# %%
## Load Experimental Data with PyCall (current dependence)
py"""
import numpy as np

def readnpyfile(x):
    file = np.load(x, allow_pickle = True)
    ratio_plot = file.item().get('ratio_plot')
    ratio_error = file.item().get('ratio_error')
    curr_plot = [curr*1e6 for curr in file.item().get('curr_plot')]
    volt_plot = np.ones_like(curr_plot)*40. 
    return ratio_plot, ratio_error, curr_plot, volt_plot
"""
y_unpat_curr = py"readnpyfile"("ratio_current_data_unpat.npy");
y_thick4_curr = py"readnpyfile"("ratio_current_data_thick4.npy");

# %%
errorbar(y_unpat_curr[3], y_unpat_curr[1], yerr=y_unpat_curr[2], fmt="o", color = "blue", label = "unpat");
errorbar(y_thick4_curr[3], y_thick4_curr[1], yerr=y_thick4_curr[2], fmt="o", color = "red", label = "pat");
ylabel("Green to read peak ratio");
xlabel("Measured current (μA)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
## Load Experimental Data with PyCall 
py"""
import numpy as np

def readnpyfile_volt(x):
    file = np.load(x, allow_pickle = True)
    ratio_plot = file.item().get('ratio_plot')
    ratio_error = file.item().get('ratio_error')
    curr_plot = [curr * 1e6 for curr in file.item().get('curr_plot')]
    volt_plot = file.item().get('volt_plot')
    return ratio_plot, ratio_error, curr_plot, volt_plot
"""
y_unpat_volt = py"readnpyfile_volt"("ratio_voltage_data_unpat.npy");
y_thick4_volt = py"readnpyfile_volt"("ratio_voltage_data_thick4.npy");

# %%
figure()
errorbar(y_unpat_volt[4], y_unpat_volt[1], yerr=y_unpat_volt[2], fmt="o", color = "blue", label = "unpat");
errorbar(y_thick4_volt[4], y_thick4_volt[1], yerr=y_thick4_volt[2], fmt="o", label = "pat", color = "red");
legend()
ylabel("Green to read peak ratio");
xlabel("Measured energy (keV)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
## Plot all data on same plot 
figure()
errorbar(y_unpat_curr[4].*y_unpat_curr[3], y_unpat_curr[1], yerr=y_unpat_curr[2], fmt="x", label = "unpat, curr", color = "blue");
errorbar(y_thick4_curr[4].*y_thick4_curr[3], y_thick4_curr[1], yerr=y_thick4_curr[2], fmt="x", label = "pat, curr", color = "red");
errorbar(y_unpat_volt[4].*y_unpat_volt[3], y_unpat_volt[1], yerr=y_unpat_volt[2], fmt="o", label = "unpat, volt", color = "blue");
errorbar(y_thick4_volt[4].*y_thick4_volt[3], y_thick4_volt[1], yerr=y_thick4_volt[2], fmt="o", label = "pat, volt", color = "red");
legend()
ylabel("Green to read peak ratio");
xlabel("Beam power (mW)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
function ene_loss_ratio(ene_kev)
    res = zeros((len(ene_kev)))
    for i in range(len(ene_kev))
        res[i] = ene_loss[argmin(abs.(ene_kev.-envals_kev))]
end;

# %%
ene_kev= 40.
ene_loss_ratio(y_thick4_curr[4])
# Out:
# DimensionMismatch("arrays could not be broadcast to a common size; got a dimension with lengths 20 and 251")
#
# Stacktrace:
#  [1] _bcs1 at ./broadcast.jl:490 [inlined]
#  [2] _bcs at ./broadcast.jl:484 [inlined]
#  [3] broadcast_shape at ./broadcast.jl:478 [inlined]
#  [4] combine_axes at /Users/charlesroques-carmes/.julia/packages/DiffEqBase/V7P18/src/diffeqfastbc.jl:23 [inlined]
#  [5] _axes at ./broadcast.jl:208 [inlined]
#  [6] axes at ./broadcast.jl:206 [inlined]
#  [7] combine_axes at ./broadcast.jl:474 [inlined]
#  [8] instantiate at ./broadcast.jl:256 [inlined]
#  [9] materialize(::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(abs),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(-),Tuple{Array{Float64,1},Array{Float64,1}}}}}) at ./broadcast.jl:820
#  [10] ene_loss_ratio(::Array{Float64,1}) at ./In[53]:2
#  [11] top-level scope at In[55]:2

# %%
## Plot all data on same plot 
figure()
errorbar(y_unpat_curr[4].*y_unpat_curr[3], y_unpat_curr[1], yerr=y_unpat_curr[2], fmt="x", label = "unpat, curr", color = "blue");
errorbar(y_thick4_curr[4].*y_thick4_curr[3], y_thick4_curr[1], yerr=y_thick4_curr[2], fmt="x", label = "pat, curr", color = "red");
errorbar(y_unpat_volt[4].*y_unpat_volt[3], y_unpat_volt[1], yerr=y_unpat_volt[2], fmt="o", label = "unpat, volt", color = "blue");
errorbar(y_thick4_volt[4].*y_thick4_volt[3], y_thick4_volt[1], yerr=y_thick4_volt[2], fmt="o", label = "pat, volt", color = "red");
legend()
ylabel("Green to read peak ratio");
xlabel("Beam power (mW)");

# %%
# Create concatenated data sets:
x_unpat = vcat(y_unpat_curr[4].*y_unpat_curr[3], y_unpat_volt[4].*y_unpat_volt[3]);
y_unpat = vcat(y_unpat_curr[1], y_unpat_volt[1]);
yerr_unpat = vcat(y_unpat_curr[2], y_unpat_volt[2]);

x_thick4 = vcat(y_thick4_curr[4].*y_thick4_curr[3], y_thick4_volt[4].*y_thick4_volt[3]);
y_thick4 = vcat(y_thick4_curr[1], y_thick4_volt[1]);
yerr_thick4 = vcat(y_thick4_curr[2], y_thick4_volt[2]);

# %% [markdown]
# # Full data fit (voltage and current dependence)
# - Create model function that takes into account current density and depth factor

# %%
function model(x, p, sol_flag = false)
    # x is power (in mW)
    ratio1 = p[1]
    ratio4 = p[2]
    scaling = p[3]
    
    Γ24_0 = 10.
    Γ34_0 = Γ24_0*ratio4    
    Γ12_0 = Γ24_0/10.
    Γ13_0 = Γ12_0/ratio1
        
    emission_ratio = zeros(size(x,1))
    t_vec = 0.
    u_vec = 0.

    for ii = 1 : size(x,1);
        params = [scaling*x[ii], Γ24_0, Γ34_0, Γ12_0, Γ13_0];

        u0 = zeros(4);
        u0[1] = 1.0;

        tspan = (0.0, 5e2);
        prob = ODEProblem(rate_solve, u0, tspan, params)
#         sol = solve(prob, Tsit5(), reltol=1e-6, abstol=1e-6);        
#         sol = solve(prob, Rosenbrock23(), reltol=1e-6, abstol=1e-6);
        sol = solve(prob, CVODE_BDF(), reltol=1e-6, abstol=1e-6);                

        emission_ratio[ii] = (params[5]*sol.u[size(sol.t,1)][3]) / (params[4]*sol.u[size(sol.t,1)][2]);    
        t_vec = sol.t
        u_vec = sol.u
    end
    if sol_flag == false
        return emission_ratio
    else
        return emission_ratio, t_vec, u_vec
    end
end;

# %%
function model2(x, p, sol_flag = false)
    ratio1 = p[1]
    ratio4 = p[2]
    scaling = p[3]
    
    Γ24_0 = 10.
    Γ34_0 = Γ24_0*ratio4    
    Γ12_0 = Γ24_0/10.
    Γ13_0 = Γ12_0/ratio1
        
    emission_ratio = zeros(size(x,1))
    t_vec = 0.
    u_vec = 0.

    for ii = 1 : size(x,1);
        params = [scaling*x[ii], Γ24_0, Γ34_0, Γ12_0, Γ13_0];

        u0 = zeros(4);
        u0[1] = 1.0;

        tspan = (0.0, 5e2);
        prob = ODEProblem(rate_solve, u0, tspan, params)
#         sol = solve(prob, Tsit5(), reltol=1e-6, abstol=1e-6);        
#         sol = solve(prob, Rosenbrock23(), reltol=1e-6, abstol=1e-6);
        sol = solve(prob, CVODE_BDF(), reltol=1e-6, abstol=1e-6);        

        emission_ratio[ii] = (params[5]*sol.u[size(sol.t,1)][3]) / (params[4]*sol.u[size(sol.t,1)][2]);    
        t_vec = sol.t
        u_vec = sol.u
    end
    if sol_flag == false
        return emission_ratio
    else
        return emission_ratio, t_vec, u_vec
    end
end;

# %%
## Unpatterned, use experimental uncertainty for weights 
# Roughly insensitive to initial state (within 5-10% )
lb = [0., 0., 0.]
ub = [50., 100.,0.1]

p0_bounds = [25., 2.5, 1/20.]

wt = 1 ./ yerr_unpat

fit_bounds_unpat = curve_fit(model, x_unpat, y_unpat, wt, p0_bounds, lower=lb, upper=ub)
# Out:
# LsqFit.LsqFitResult{Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,1}}([13.519775532640605, 2.7194429341533635, 4.5364280401685e-5], [-0.09587802078697616, 0.4049314045406657, 0.5598963611744634, 1.2690592158681218, 0.7399078216084305, -0.47973921016261617, -1.45980091072426, -1.791827292918254, -1.9382821503709706, -0.12097969144412866, 0.08359149329873525, 1.0433019749357582, 0.33666577135363157, 0.11003666384218576, 0.3438488951749745, 0.6290114393493726], [-0.08833552160359329 0.9856006193881053 -21191.95006526072; -0.04082915747169116 1.6940627076919914 -11097.240932941246; … ; -0.1194961776497563 1.5719124556338386 -29747.592465729987; -0.19235729069453616 1.6769809629952037 -34537.855942336675], true, [7.357865698306704, 4.940238531150563, 3.6648049454423335, 14.792285984995818, 15.76466973861617, 13.979588637703287, 8.471505424710768, 9.571629833071206, 7.055932668540983, 10.821821210855635, 5.6403152306845, 7.838912111886239, 7.906212153475122, 13.615032713883052, 13.584836685514228, 18.87196390055235])

# %%
# plot(xdata_unpat, model(xdata_unpat, p0_bounds), "o")
x_unpat_plot = [minimum(x_unpat):1.0:maximum(x_unpat);]
plot(sort(x_unpat_plot), model(sort(x_unpat_plot), fit_bounds_unpat.param), "--", label = "model", color = "blue")
errorbar(x_unpat, y_unpat, yerr = yerr_unpat, fmt = "o", label = "data (unpat.)", color = "blue");
legend()
xlabel("Beam power (mW)")
ylabel("Green to red ratio")
title("Unpatterned fit (volt. and curr.)")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'Unpatterned fit (volt. and curr.)')

# %%
# Check time convergence of solver 
x_test = x_unpat[1]
_, t_test, u_test = model(x_test, fit_bounds_unpat.param, true)

# x_test = xdata_thick4[end]
# _, t_test, u_test = model(x_test, fit_bounds_thick4.param, true)
plot(t_test, u_test);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
## Same thing, but remove smallest current points 
lb = [0., 0., 0.]
ub = [2000., 100.,1.]

p0_bounds = [50., 2.5, 1/20.]

remove_indices = 6
sorted_indices = sortperm(x_unpat)
x_unpat_red = [x_unpat[i] for i in sorted_indices[remove_indices:end]]
y_unpat_red = [y_unpat[i] for i in sorted_indices[remove_indices:end]]
yerr_unpat_red = [yerr_unpat[i] for i in sorted_indices[remove_indices:end]]

wt = 1 ./ yerr_unpat_red

fit_bounds_unpat00 = curve_fit(model, x_unpat_red, y_unpat_red, wt, p0_bounds, lower=lb, upper=ub)
# Out:
# LsqFit.LsqFitResult{Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,1}}([34.81387499950545, 4.536957673347225, 5.960413614659602e-5], [1.2396902675380002, -1.0868411021734916, 0.7837914324927026, -1.2355855721884312, -1.1732682642947068, -0.4044413859998502, 0.5151876954175278, 0.1319626773258286, 0.9087352088148652, 0.20190366455118144, -0.41754796728287535], [-0.06595959744439941 1.5443052005873306 -37013.13824092202; -0.05389217381794179 1.136209653850973 -30086.012474527754; … ; -0.07029077191936112 0.808368217061356 -36188.966717327065; -0.041831962507317806 0.4913245033005489 -21167.89535850701], true, [10.821821210855635, 7.055932668540983, 13.615032713883052, 9.571629833071206, 8.471505424710768, 13.979588637703287, 15.76466973861617, 13.584836685514228, 14.792285984995818, 18.87196390055235, 7.357865698306704])

# %%
# plot(xdata_unpat, model(xdata_unpat, p0_bounds), "o")
x_unpat_plot = [minimum(x_unpat_red):1.0:maximum(x_unpat_red);]
plot(sort(x_unpat_plot), model(sort(x_unpat_plot), fit_bounds_unpat00.param), "--", label = "model", color = "blue")
errorbar(y_unpat_curr[4].*y_unpat_curr[3], y_unpat_curr[1], yerr=y_unpat_curr[2], fmt="x", label = "unpat, curr", color = "blue");
errorbar(y_unpat_volt[4].*y_unpat_volt[3], y_unpat_volt[1], yerr=y_unpat_volt[2], fmt="o", label = "unpat, volt", color = "blue");
legend();
xlabel("Beam power (mW)")
ylabel("Green to red ratio")
title("Unpatterned fit (volt. and curr.)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Comparison of different methods (unpatterned)

# %%
function evaluate_method(fit, title)
    p1, p2, p3 = fit.param
    margin_of_error = margin_error(fit)
    confidence_intervals = confidence_interval(fit)
    std_error = stderror(fit)
    print(title, " \n")    
    @printf("Γ24 = 10., Γ34 = Γ24*%.2e, Γ12 = Γ24 / 10. and Γ13 = Γ12 / %.2e Γ14 = %.2e * current (μA) \n", p2, p1, p3)
    @printf("fit parameters: %.2e, %.2e, %.2e \n", p1, p2, p3)
    print("error: \n")
    map(x -> @printf("%.2e  ",x), std_error)
    print("\n error (%): \n")    
    map(x -> @printf("%.2e  ",x), std_error./fit.param*100)    
    print("\n \n")        
end;
evaluate_method(fit_bounds_unpat, "Experimental uncertainty")
evaluate_method(fit_bounds_unpat00, "Remove low current plateau")
# Out:
# Experimental uncertainty
# Γ24 = 10., Γ34 = Γ24*2.72e+00, Γ12 = Γ24 / 10. and Γ13 = Γ12 / 1.35e+01 Γ14 = 4.54e-05 * current (μA)
# fit parameters: 1.35e+01, 2.72e+00, 4.54e-05
# error:
# 1.79e+01  3.47e-02  7.45e-05
#  error (%):
# 1.32e+02  1.28e+00  1.64e+02
#
# Remove low current plateau
# Γ24 = 10., Γ34 = Γ24*4.54e+00, Γ12 = Γ24 / 10. and Γ13 = Γ12 / 3.48e+01 Γ14 = 5.96e-05 * current (μA)
# fit parameters: 3.48e+01, 4.54e+00, 5.96e-05
# error:
# 4.92e+01  1.41e+00  1.10e-04
#  error (%):
# 1.41e+02  3.10e+01  1.85e+02

# %% [markdown]
# # Patterned data

# %%
# To try: clamping and not clamping
# Experimental and numerical uncertainty
p_unpat = fit_bounds_unpat00.param # Take the one that has the lowest uncertainty

lb = [0., 0., 0.]
ub = [2000., 100.,1.]

p0_bounds = [p_unpat[1], p_unpat[2], p_unpat[3]]

wt = 1 ./ yerr_thick4

fit_bounds_thick4_00 = curve_fit(model, x_thick4, y_thick4, wt, p0_bounds, lower=lb, upper=ub)
# Out:
# LsqFit.LsqFitResult{Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,1}}([111.8908687170322, 4.297634576513889, 0.00018116861135908382], [0.12307444150578102, 0.39797716281552525, 0.09776472432668626, -0.034019686186287486, -0.05420737966255929, 0.10264187442619294, 0.3744075409249335, 0.639052148645226, 1.2066466093256694, 0.7591445235196721  …  0.40602783323505254, -0.002758730729019844, 0.4075348998626707, -1.6299547047561709, -0.8594840775187425, -1.8658213381552924, -1.155390399041465, -2.536654281487603, -1.3064063370937815, -0.19142209387998987], [-0.011899421491299989 0.39126214594959935 -6080.903641405735; -0.016519184161422635 0.6549936522430634 -9420.764837227147; … ; -0.009749739307807433 0.3143076428731578 -5131.937575221507; -0.012393728128458492 0.39681123709281685 -6477.935618948489], true, [24.961034669757026, 21.356716856856966, 26.626180531669938, 23.84848327398141, 19.624869090500205, 17.138975994347128, 12.710045080345392, 11.368920806259784, 17.443771103049826, 7.560583544358656  …  26.9637378948538, 22.99695484086426, 19.431180928203084, 1.9006846346503523, 11.386632905483472, 18.191602860789974, 8.298340320555525, 25.691323020359757, 14.260486948957874, 24.009253247503924])

# %%
xdata_thick4_plot = [8.0:0.5:maximum(x_thick4);]
plot(sort(xdata_thick4_plot), model(sort(xdata_thick4_plot), fit_bounds_thick4_00.param), "--", label = "model", color = "red")
errorbar(y_thick4_curr[4].*y_thick4_curr[3], y_thick4_curr[1], yerr=y_thick4_curr[2], fmt="x", label = "pat, curr", color = "red");
errorbar(y_thick4_volt[4].*y_thick4_volt[3], y_thick4_volt[1], yerr=y_thick4_volt[2], fmt="o", label = "pat, volt", color = "red");
xlabel("Beam power (mW)")
ylabel("Green to red ratio")
title("Thick4 (patterned) fit (volt. and curr.)")
legend();
# ylim([0, 1.75])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
evaluate_method(fit_bounds_thick4_00, "Experimental uncertainty, unclamped")
# Out:
# Experimental uncertainty, unclamped
# Γ24 = 10., Γ34 = Γ24*4.30e+00, Γ12 = Γ24 / 10. and Γ13 = Γ12 / 1.12e+02 Γ14 = 1.81e-04 * current (μA)
# fit parameters: 1.12e+02, 4.30e+00, 1.81e-04
# error:
# 4.32e+01  8.53e-03  8.55e-05
#  error (%):
# 3.86e+01  1.99e-01  4.72e+01

# %%
function fit_comparison(fit_unpat, fit_pat)
    p1_thick4, p2_thick4, p3_thick4 = fit_pat.param
    p1_unpat, p2_unpat, p3_unpat = fit_unpat.param
    enhancement = p1_thick4/p1_unpat
    current_scaling_ratio = p3_thick4/p3_unpat
    @printf("Patterned to unpatterned Γ12 / Γ13 enhancement = %.2e \n", enhancement)
    @printf("Patterned to unpatterned current scaling ratio = %.2e", current_scaling_ratio)        
    print("\n \n")            
end;

# %%
# Analysis of the fits:
fit_unpat = fit_bounds_unpat00
evaluate_method(fit_bounds_thick4_00, "Experimental uncertainty, unclamped (Tsit5)")
fit_comparison(fit_unpat, fit_bounds_thick4_00)

# evaluate_method(fit_bounds_thick4_01, "Experimental uncertainty, clamped (Tsit5 and CVODE)")
# fit_comparison(fit_unpat, fit_bounds_thick4_01)

# evaluate_method(fit_bounds_thick4_10, "Numerical uncertainty, unclamped (Tsit5)")
# fit_comparison(fit_unpat, fit_bounds_thick4_10)

# evaluate_method(fit_bounds_thick4_11, "Numerical uncertainty, clamped (Tsit5 and CVODE)")
# fit_comparison(fit_unpat, fit_bounds_thick4_11)
# Out:
# Experimental uncertainty, unclamped (Tsit5)
# Γ24 = 10., Γ34 = Γ24*4.30e+00, Γ12 = Γ24 / 10. and Γ13 = Γ12 / 1.12e+02 Γ14 = 1.81e-04 * current (μA)
# fit parameters: 1.12e+02, 4.30e+00, 1.81e-04
# error:
# 4.32e+01  8.53e-03  8.55e-05
#  error (%):
# 3.86e+01  1.99e-01  4.72e+01
#
# Patterned to unpatterned Γ12 / Γ13 enhancement = 3.21e+00
# Patterned to unpatterned current scaling ratio = 3.04e+00

# %% [markdown]
# - Let's try to have some energy-dependent prop. factor in the $\Gamma_{41} = \eta(E) E * I$, where $\eta(E)$ accounts for energy-dependent penetration depth
# - Then the effective "power" will be lower for energies below 40 keV (because the overlap with the loss region is small), so the voltage data points for patterned will get closer to fit (and fit will be easier)
# - The question is what is the functional dependence of $\eta(E)$? Let's wait to see what Nick gets from CASINO.
# I guess we should have something like: $\eta(E) \propto \int_{V_\text{lum}} \rho(E) \sim \text{sigmoid} [\alpha (E-E_0)]$
# - Fit voltage independently and account for depth (CASINO or model)
